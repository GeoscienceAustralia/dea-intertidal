# %% [markdown]
# # Digital Earth Australia Intertidal Command Line Interfaces (CLI)
#
# This notebook demonstrates how to call the DEA Intertidal and DEA Intertidal Composites workflows via their Command Line Interface utilities.
# This allows you to run an entire DEA Intertidal Analysis using a single line of code.
#
# ## Getting started
# Set working directory to top level of repo to ensure links work correctly:

# %%
cd ../..
# Out:
# /home/jovyan/Robbi/dea-intertidal

# %% [markdown]
# Install the latest version of `dea-intertidal`:

# %%
# %pip install -e .

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Set analysis parameters
# Sets the 32 km coastal grid cell to analyse, the config file, start and end dates, and other more specific parameters.

# %%
# General params
study_area = "testing"  # To match the default 32 km tile GridSpec, e.g. "x174y083"
start_date = "2018"  # Start date for analysis
label_date = "2019"  # Date used to label arrays
end_date = "2020"  # End date for analysis
tide_model = "ensemble"  # "EOT20"  # Tide model to use in analysis
tide_model_dir = "/var/share/tide_models/"  # Directory containing tide model files
output_version = "testing"  # Version number to label output files and metadata
output_dir = "data/processed/"  # Path for output files, can also be e.g. "s3://dea-public-data-dev/derivative/"

# Intertidal Exposure params
modelled_freq = "3h"

# Additional flags optionally turning exposure/offset calculation off
# for testing elevation code
exposure_offsets = "--exposure_offsets"

# %% [markdown]
# ## DEA Intertidal CLI
# This CLI allows you to generate the following DEA Intertidal layers with a single command line call:
# * **DEA Intertidal Elevation**
# * **DEA Intertidal Exposure**
# * **DEA Intertidal Extents**
# * **DEA Intertidal spread, offsets, HOT, LOT, HAT, LAT**
#
# Running `--help` shows all the CLI parameters that can be used to customise the analysis:

# %%
# !python -m intertidal.elevation --help
# Out:
# Usage: python -m intertidal.elevation [OPTIONS]
#
# Options:
#   --study_area TEXT               A string providing a GridSpec tile ID (e.g.
#                                   in the form 'x123y123') to run the analysis
#                                   on.  [required]
#   --start_date TEXT               The start date of satellite data to load
#                                   from the datacube. This can be any date
#                                   format accepted by datacube. For DEA
#                                   Intertidal, this is set to provide a three
#                                   year window centred over `label_date` below.
#                                   [required]
#   --end_date TEXT                 The end date of satellite data to load from
#                                   the datacube. This can be any date format
#                                   accepted by datacube. For DEA Intertidal,
#                                   this is set to provide a three year window
#                                   centred over `label_date` below.  [required]
#   --label_date TEXT               The date used to label output arrays, and to
#                                   use as the date assigned to the dataset when
#                                   indexed into Datacube.  [required]
#   --output_version TEXT           The version number to use for output files
#                                   and metadata (e.g. '0.0.1').  [required]
#   --output_dir TEXT               The directory/location to output data and
#                                   metadata; supports both local disk and S3
#                                   locations. Defaults to 'data/processed/'.
#   --product_maturity TEXT         Product maturity metadata to use for the
#                                   output dataset. Defaults to 'stable', can
#                                   also be 'provisional'.
#   --dataset_maturity TEXT         Dataset maturity metadata to use for the
#                                   output dataset. Defaults to 'final', can
#                                   also be 'interim'.
#   --resolution INTEGER            The spatial resolution in metres used to
#                                   load satellite data and produce intertidal
#                                   outputs. Defaults to 10 metre Sentinel-2
#                                   resolution.
#   --ndwi_thresh FLOAT             NDWI threshold used to identify the
#                                   transition from dry to wet in the intertidal
#                                   elevation calculation. Defaults to 0.1,
#                                   which typically captures this transition
#                                   more reliably than 0.0.
#   --min_freq FLOAT                Minimum frequency of wetness required for a
#                                   pixel to be included in the analysis, by
#                                   default 0.01.
#   --max_freq FLOAT                Maximum frequency of wetness required for a
#                                   pixel to be included in the analysis, by
#                                   default 0.99.
#   --min_correlation FLOAT         Minimum correlation between water index and
#                                   tide height required for a pixel to be
#                                   included in the analysis, by default 0.15.
#   --windows_n INTEGER             Number of rolling windows to iterate over in
#                                   the per-pixel rolling median calculation, by
#                                   default 100.
#   --window_prop_tide FLOAT        Proportion of the tide range to use for each
#                                   window radius in the per-pixel rolling
#                                   median calculation, by default 0.15.
#   --correct_seasonality / --no-correct_seasonality
#                                   If True, remove any seasonal signal from the
#                                   tide height data by subtracting monthly mean
#                                   tide height from each value prior to
#                                   correlation calculations. This can reduce
#                                   false tide correlations in regions where
#                                   tide heights correlate with seasonal changes
#                                   in surface water. Note that seasonally
#                                   corrected tides are only used to identify
#                                   potentially tide influenced pixels - not for
#                                   elevation modelling itself.
#   --tide_model TEXT               The model used for tide modelling, as
#                                   supported by the `eo-tides` Python package.
#                                   Options include 'EOT20' (default),
#                                   'TPXO10-atlas-v2-nc', 'FES2022', 'FES2014',
#                                   'GOT5.6', 'ensemble'.
#   --tide_model_dir TEXT           The directory containing tide model data
#                                   files. Defaults to '/var/share/tide_models';
#                                   for more information about the required
#                                   directory structure, refer to `eo-
#                                   tides.utils.list_models`.
#   --modelled_freq TEXT            The frequency at which to model tides across
#                                   the entire analysis period as inputs to the
#                                   exposure, LAT (lowest astronomical tide),
#                                   HAT (highest astronomical tide), and
#                                   spread/offset calculations. Defaults to
#                                   '30min' which will generate a timestep every
#                                   30 minutes between 'start_date' and
#                                   'end_date'.
#   --exposure_offsets / --no-exposure_offsets
#                                   Whether to run the Exposure and
#                                   spread/offsets/tidelines steps of the
#                                   Intertidal workflow. Defaults to True; can
#                                   be set to False by passing `--no-
#                                   exposure_offsets`.
#   --aws_unsigned / --no-aws_unsigned
#                                   Whether to sign AWS requests for S3 access.
#                                   Defaults to True; can be set to False by
#                                   passing `--no-aws_unsigned`.
#   --help                          Show this message and exit.

# %% [markdown]
# ### Run DEA Intertidal CLI for a single epoch
# This will run an entire DEA Intertidal analysis from start to finish:

# %%
# %%time
# !python -m intertidal.elevation --study_area {study_area} --start_date {start_date} --end_date {end_date} --label_date {label_date} --output_dir {output_dir} --output_version {output_version} --modelled_freq {modelled_freq} --exposure_offsets {exposure_offsets} --tide_model {tide_model} --tide_model_dir {tide_model_dir}

# %% [markdown]
# ### Run DEA Intertidal CLI for a single epoch with multiple tiles
# This will run an entire DEA Intertidal analysis from start to finish:

# %%
study_area_list = ["x137y175"]
# study_area_list = ["testing"]
epoch_list = [
    # ("2016", "2017", "2018"),
    # ("2017", "2018", "2019"),
    # ("2018", "2019", "2020"),
    ("2019", "2020", "2021"),
]

for tile in study_area_list:
    for start_date, label_date, end_date in epoch_list:
        print(start_date, label_date, end_date)
        print(tile)
        try:
            # !python -m intertidal.elevation --study_area {tile} --start_date {start_date} --end_date {end_date} --label_date {label_date} --output_dir {output_dir} --output_version {output_version} --modelled_freq {modelled_freq} --exposure_offsets {exposure_offsets} --tide_model {tide_model} --tide_model_dir {tide_model_dir}
        except:
            pass
# Out:
# 2019 2020 2021
# x137y175
# 2025-12-18 00:00:25 INFO [testing] [2020] [x137y175]: Using parameters {'study_area': 'x137y175', 'start_date': '2019', 'end_date': '2021', 'label_date': '2020', 'output_version': 'testing', 'output_dir': 'data/processed/', 'product_maturity': 'stable', 'dataset_maturity': 'final', 'resolution': 10, 'ndwi_thresh': 0.1, 'min_freq': 0.01, 'max_freq': 0.99, 'min_correlation': 0.15, 'windows_n': 100, 'window_prop_tide': 0.15, 'correct_seasonality': False, 'tide_model': ('ensemble',), 'tide_model_dir': '/var/share/tide_models/', 'modelled_freq': '3h', 'exposure_offsets': True, 'aws_unsigned': True, 'datacube': <module 'datacube' from '/env/lib/python3.10/site-packages/datacube/__init__.py'>, 'configure_s3_access': <function configure_s3_access at 0x7fba44391000>}
# 2025-12-18 00:00:25 INFO [testing] [2020] [x137y175]: Loading satellite data
# <Client: 'tcp://127.0.0.1:35179' processes=1 threads=64, memory=456.00 GiB>
# 2025-12-18 00:00:47 INFO [testing] [2020] [x137y175]: Loading 479 satellite data timesteps
# ERROR:datacube.storage._rio:Error opening source dataset: s3://dea-public-data/baseline/ga_s2bm_ard_3/52/LHM/2020/09/08/20200908T024745/ga_s2bm_nbart_3-2-1_52LHM_2020-09-08_final_band03.tif
# WARNING:datacube.utils.py:Ignoring Exception: Read failed. See previous exception for details.
# Loading SRTM data at native 30 m resolution
# Adding GMW mangroves to starting points
# Applying HAT correction
# Running cost distance calculation
# Reprojecting back to original GeoBox resolution
# 2025-12-18 00:14:14 INFO [testing] [2020] [x137y175]: Calculating Intertidal Elevation
# 2025-12-18 00:14:14 INFO [testing] [2020] [x137y175]: Modelling tide heights for each pixel
# Creating reduced resolution 5000 x 5000 metre tide modelling array
# Running ensemble tide modelling
# Modelling tides with EOT20, FES2012, FES2014_extrapolated, FES2022_extrapolated, GOT4.10, GOT5.6_extrapolated, TPXO10-atlas-v2-nc, TPXO8-atlas-nc, TPXO9-atlas-v5-nc in parallel (models: 9, splits: 1)
# 100%|█████████████████████████████████████████████| 9/9 [00:30<00:00,  3.42s/it]
# Interpolating model rankings using IDW interpolation
# Combining models into single ensemble model
# Reprojecting tides into original resolution
# 2025-12-18 00:15:25 INFO [testing] [2020] [x137y175]: Masking nodata and adding tide heights to satellite data array
# 2025-12-18 00:15:47 INFO [testing] [2020] [x137y175]: Flattening satellite data array and filtering to intertidal candidate pixels
# 2025-12-18 00:15:47 INFO [testing] [2020] [x137y175]: Applying valid data mask to constrain study area
# Reducing analysed pixels from 10240000 to 508176 (4.96%)
# 2025-12-18 00:18:47 INFO [testing] [2020] [x137y175]: Running per-pixel rolling median
# 100%|█████████████████████████████████████████| 105/105 [09:59<00:00,  5.71s/it]
# 2025-12-18 00:29:00 INFO [testing] [2020] [x137y175]: Modelling intertidal elevation
# Applying tidal interval interpolation to 200 intervals
# Applying rolling mean smoothing with radius 20
# 2025-12-18 00:29:05 INFO [testing] [2020] [x137y175]: Modelling intertidal uncertainty
# 2025-12-18 00:29:38 INFO [testing] [2020] [x137y175]: Unflattening data back to its original spatial dimensions
# 2025-12-18 00:29:40 INFO [testing] [2020] [x137y175]: Cleaning inaccurate upper intertidal pixels
# 2025-12-18 00:29:40 INFO [testing] [2020] [x137y175]: Successfully completed intertidal elevation modelling
# 2025-12-18 00:29:40 INFO [testing] [2020] [x137y175]: Calculating Intertidal Extents
# 2025-12-18 00:29:41 INFO [testing] [2020] [x137y175]: Calculating Intertidal Exposure
# Creating reduced resolution 5000 x 5000 metre tide modelling array
# Running ensemble tide modelling
# Modelling tides with EOT20, FES2012, FES2014_extrapolated, FES2022_extrapolated, GOT4.10, GOT5.6_extrapolated, TPXO10-atlas-v2-nc, TPXO8-atlas-nc, TPXO9-atlas-v5-nc in parallel (models: 9, splits: 1)
# 100%|█████████████████████████████████████████████| 9/9 [01:09<00:00,  7.73s/it]
# Interpolating model rankings using IDW interpolation
# Combining models into single ensemble model
# Returning low resolution tide array
# Calculating unfiltered exposure
# 2025-12-18 00:31:55 INFO [testing] [2020] [x137y175]: Calculating spread, offset and HAT/LAT/LOT/HOT layers
# Using tide modelling location: 131.86, -12.29
# Running ensemble tide modelling
# Modelling tides with EOT20, FES2012, FES2014_extrapolated, FES2022_extrapolated, GOT4.10, GOT5.6_extrapolated, TPXO10-atlas-v2-nc, TPXO8-atlas-nc, TPXO9-atlas-v5-nc in parallel (models: 9, splits: 1)
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.73s/it]
# Interpolating model rankings using IDW interpolation
# Combining models into single ensemble model
# Using tide modelling location: 131.86, -12.29
# Running ensemble tide modelling
# Modelling tides with EOT20, FES2012, FES2014_extrapolated, FES2022_extrapolated, GOT4.10, GOT5.6_extrapolated, TPXO10-atlas-v2-nc, TPXO8-atlas-nc, TPXO9-atlas-v5-nc in parallel (models: 9, splits: 1)
# 100%|█████████████████████████████████████████████| 9/9 [00:21<00:00,  2.36s/it]
# Interpolating model rankings using IDW interpolation
# Combining models into single ensemble model
# 2025-12-18 00:34:23 INFO [testing] [2020] [x137y175]: Assembling dataset
# 2025-12-18 00:34:23 INFO [testing] [2020] [x137y175]: Writing output arrays
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# 2025-12-18 00:34:38 INFO [testing] [2020] [x137y175]: Assembled dataset: /tmp/tmpt_a3crar/ga_s2ls_intertidal_cyear_3/testing/x137/y175/2020--P1Y/ga_s2ls_intertidal_cyear_3_x137y175_2020--P1Y_final.odc-metadata.yaml
# 2025-12-18 00:34:39 INFO [testing] [2020] [x137y175]: Writing data locally: data/processed/ga_s2ls_intertidal_cyear_3/testing/x137/y175/2020--P1Y/
# 2025-12-18 00:34:40 INFO [testing] [2020] [x137y175]: Completed DEA Intertidal workflow

# %% [markdown]
# ## DEA Tidal Composites CLI
#
# This CLI allows you to generate the following DEA Intertidal layers with a single command line call:
#
# * **DEA Tidal Composites** (producing low and high tide geomedian outputs)
#
# Running `--help` shows all the CLI parameters that can be used to customise the analysis:

# %%
# !python -m intertidal.composites --help
# Out:
# Usage: python -m intertidal.composites [OPTIONS]
#
# Options:
#   --study_area TEXT               A string providing a GridSpec tile ID (e.g.
#                                   in the form 'x123y123') to run the analysis
#                                   on.  [required]
#   --start_date TEXT               The start date of satellite data to load
#                                   from the datacube. This can be any date
#                                   format accepted by datacube. For DEA Tidal
#                                   Composites, this is set to provide a three
#                                   year window centred over `label_date` below.
#                                   [required]
#   --end_date TEXT                 The end date of satellite data to load from
#                                   the datacube. This can be any date format
#                                   accepted by datacube. For DEA Tidal
#                                   Composites, this is set to provide a three
#                                   year window centred over `label_date` below.
#                                   [required]
#   --label_date TEXT               The date used to label output arrays, and to
#                                   use as the date assigned to the dataset when
#                                   indexed into Datacube.  [required]
#   --output_version TEXT           The version number to use for output files
#                                   and metadata (e.g. '0.0.1').  [required]
#   --output_dir TEXT               The directory/location to output data and
#                                   metadata; supports both local disk and S3
#                                   locations. Defaults to 'data/processed/'.
#   --product_maturity TEXT         Product maturity metadata to use for the
#                                   output dataset. Defaults to 'provisional',
#                                   can also be 'stable'.
#   --dataset_maturity TEXT         Dataset maturity metadata to use for the
#                                   output dataset. Defaults to 'final', can
#                                   also be 'interim'.
#   --resolution INTEGER            The spatial resolution in metres used to
#                                   load satellite data and produce tidal
#                                   composite outputs. Defaults to 10 metre
#                                   Sentinel-2 resolution.
#   --threshold_lowtide FLOAT       The quantile used to identify low tide
#                                   observations. Defaults to 0.15.
#   --threshold_hightide FLOAT      The quantile used to identify high tide
#                                   observations. Defaults to 0.85.
#   --min_obs INTEGER               Minimum number of clear observations to
#                                   enforce when calculating tide height
#                                   thresholds. Defaults to 0, which will not
#                                   apply any minimum.
#   --mask_sunglint INTEGER         Whether to mask out pixels that are likely
#                                   to be affected by sunglint using glint
#                                   angles. Low glint angles (e.g. < 20) often
#                                   correspond with sunglint. Defaults to 20,
#                                   which will mask all pixels with a glint
#                                   angle of less than 20.
#   --gqa_filter / --no-gqa_filter  Whether to filter scenes when loading data
#                                   based on gqa values. Defaults to True
#   --include_coastal_aerosol / --no-include_coastal_aerosol
#                                   Whether to include the coastal aerosol band.
#                                   Defaults to True
#   --eps FLOAT                     Termination criteria passed on to the
#                                   geomedian algorithm.
#   --cpus INTEGER                  Requested number of CPUs which is passed on
#                                   to the geomedian function.
#   --max_iters INTEGER             Maximum number of iterations done per output
#                                   pixel in the geomedian calculation. This can
#                                   be set to a low value (e.g. 10) to increase
#                                   the processing speed of test runs.
#   --tide_model TEXT               The model used for tide modelling, as
#                                   supported by the `eo-tides` Python package.
#                                   Options include 'EOT20' (default),
#                                   'TPXO10-atlas-v2-nc', 'FES2022', 'FES2014',
#                                   'GOT5.6', 'ensemble'.
#   --tide_model_dir TEXT           The directory containing tide model data
#                                   files. Defaults to '/var/share/tide_models';
#                                   for more information about the required
#                                   directory structure, refer to `eo-
#                                   tides.utils.list_models`.
#   --aws_unsigned / --no-aws_unsigned
#                                   Whether to use sign AWS requests for S3
#                                   access
#   --overwrite / --no-overwrite    Whether to overwrite tile data if it already
#                                   exists.
#   --help                          Show this message and exit.

# %% [markdown]
# ### Run DEA Tidal Composites CLI for a single epoch
# This will run an entire DEA Intertidal Composites analysis from start to finish:

# %%
# General params
study_area = "testing"  # To match the default 32 km tile GridSpec, e.g. "x153y163"
start_date = "2018"  # Start date for analysis
label_date = "2019"  # Date used to label arrays
end_date = "2020"  # End date for analysis
tide_model = "ensemble"  # Tide model to use in analysis
tide_model_dir = "/var/share/tide_models/"  # Directory containing tide model files
output_version = "testing"  # Version number to label output files and metadata
output_dir = "data/processed/"  # Path for output files, can also be e.g. "s3://dea-public-data-dev/derivative/"

# Intertidal Composites params
threshold_lowtide = 0.15
threshold_hightide = 0.85
mask_sunglint = 20
max_iters = 10

# %%
# %%time
# !python -m intertidal.composites --study_area {study_area} --start_date {start_date} --end_date {end_date} --label_date {label_date}  --output_dir {output_dir} --output_version {output_version} --tide_model {tide_model} --tide_model_dir {tide_model_dir} --mask_sunglint {mask_sunglint} --max_iters {max_iters} --overwrite --threshold_lowtide {threshold_lowtide} --threshold_hightide {threshold_hightide}
# Out:
# 2025-12-18 00:38:02 INFO [testing] [2019] [testing]: Using parameters {'study_area': 'testing', 'start_date': '2018', 'end_date': '2020', 'label_date': '2019', 'output_version': 'testing', 'output_dir': 'data/processed/', 'product_maturity': 'provisional', 'dataset_maturity': 'final', 'resolution': 10, 'threshold_lowtide': 0.15, 'threshold_hightide': 0.85, 'min_obs': 0, 'mask_sunglint': 20, 'gqa_filter': True, 'include_coastal_aerosol': True, 'eps': 0.0001, 'cpus': None, 'max_iters': 10, 'tide_model': ('ensemble',), 'tide_model_dir': '/var/share/tide_models/', 'aws_unsigned': True, 'overwrite': True, 'datacube': <module 'datacube' from '/env/lib/python3.10/site-packages/datacube/__init__.py'>, 'configure_s3_access': <function configure_s3_access at 0x7f96d31767a0>, 'filename': 'data/processed/ga_s2_tidal_composites_cyear_3/testing/test/ing/2019--P1Y/ga_s2_tidal_composites_cyear_3_testing_2019--P1Y_final.stac-item.json', 'process_tile': True}
# <Client: 'tcp://127.0.0.1:38655' processes=1 threads=64, memory=456.00 GiB>
# 2025-12-18 00:38:08 INFO [testing] [2019] [testing]: Running in testing mode using custom study area
# 2025-12-18 00:38:12 INFO [testing] [2019] [testing]: Found 191 satellite data timesteps
# 2025-12-18 00:38:12 INFO [testing] [2019] [testing]: Running DEA Tidal Composites workflow
# 2025-12-18 00:38:12 INFO [testing] [2019] [testing]: Modelling tide heights for each pixel
# Creating reduced resolution 5000 x 5000 metre tide modelling array
# Running ensemble tide modelling
# Modelling tides with EOT20, FES2012, FES2014_extrapolated, FES2022_extrapolated, GOT4.10, GOT5.6_extrapolated, TPXO10-atlas-v2-nc, TPXO8-atlas-nc, TPXO9-atlas-v5-nc in parallel (models: 9, splits: 1)
# 100%|█████████████████████████████████████████████| 9/9 [00:25<00:00,  2.85s/it]
# Interpolating model rankings using IDW interpolation
# Combining models into single ensemble model
# Reprojecting tides into original resolution
# 2025-12-18 00:38:43 INFO [testing] [2019] [testing]: Loading red band to identify nodata pixels
# 2025-12-18 00:39:17 INFO [testing] [2019] [testing]: Calculating low and high tide thresholds with minimum 0 observations
# 2025-12-18 00:39:18 INFO [testing] [2019] [testing]: Loading 30 low tide satellite images into memory
# 2025-12-18 00:39:31 INFO [testing] [2019] [testing]: Loading 29 high tide satellite images into memory
# 2025-12-18 00:39:44 INFO [testing] [2019] [testing]: Running low tide geomedian with 62 threads
# 2025-12-18 00:39:44 INFO [testing] [2019] [testing]: Running high tide geomedian with 62 threads
# 2025-12-18 00:39:45 INFO [testing] [2019] [testing]: Calculating clear counts
# Using tide modelling location: 136.33, -15.60
# Running ensemble tide modelling
# Modelling tides with EOT20, FES2012, FES2014_extrapolated, FES2022_extrapolated, GOT4.10, GOT5.6_extrapolated, TPXO10-atlas-v2-nc, TPXO8-atlas-nc, TPXO9-atlas-v5-nc in parallel (models: 9, splits: 1)
# 100%|█████████████████████████████████████████████| 9/9 [00:23<00:00,  2.62s/it]
# Interpolating model rankings using IDW interpolation
# Combining models into single ensemble model
# Using tide modelling location: 136.33, -15.60
# Running ensemble tide modelling
# Modelling tides with EOT20, FES2012, FES2014_extrapolated, FES2022_extrapolated, GOT4.10, GOT5.6_extrapolated, TPXO10-atlas-v2-nc, TPXO8-atlas-nc, TPXO9-atlas-v5-nc in parallel (models: 9, splits: 1)
# 100%|█████████████████████████████████████████████| 9/9 [00:21<00:00,  2.41s/it]
# Interpolating model rankings using IDW interpolation
# Combining models into single ensemble model
# 2025-12-18 00:40:36 INFO [testing] [2019] [testing]: Assembling dataset
# 2025-12-18 00:40:36 INFO [testing] [2019] [testing]: Writing output arrays
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# 2025-12-18 00:40:37 INFO [testing] [2019] [testing]: Assembled dataset: /tmp/tmp9qhrmwv7/ga_s2_tidal_composites_cyear_3/testing/tes/ting/2019--P1Y/ga_s2_tidal_composites_cyear_3_testing_2019--P1Y_final.odc-metadata.yaml
# 2025-12-18 00:40:37 INFO [testing] [2019] [testing]: Writing data locally: data/processed/ga_s2_tidal_composites_cyear_3/testing/tes/ting/2019--P1Y/
# 2025-12-18 00:40:39 INFO [testing] [2019] [testing]: Completed DEA Tidal Composites workflow
# CPU times: user 1.16 s, sys: 350 ms, total: 1.51 s
# Wall time: 2min 43s

# %% [markdown]
# ### Run DEA Tidal Composites CLI for multiple tiles
# This will run an entire DEA Intertidal and DEA Intertidal Composites analysis from start to finish for several tiles:

# %%
start_date = "2021"  # Start date for analysis
label_date = "2022"  # Date used to label arrays
end_date = "2023"  # End date for analysis
tide_model = "ensemble"  # Tide model to use in analysis
tide_model_dir = "/var/share/tide_models/"  # Directory containing tide model files
output_version = "testing"  # Version number to label output files and metadata

# Intertidal Composites params
threshold_lowtide = 0.15
threshold_hightide = 0.85

# %%
study_area_list = ["x137y175"]
# study_area_list = ["testing"]

for study_area in study_area_list:
    print(tile)
    try:
        # !python -m intertidal.composites --study_area {study_area} --start_date {start_date} --end_date {end_date} --label_date {label_date}  --output_dir {output_dir} --output_version {output_version} --tide_model {tide_model} --tide_model_dir {tide_model_dir} --no-overwrite --threshold_lowtide {threshold_lowtide} --threshold_hightide {threshold_hightide}
    except:
        pass
# Out:
# x137y175
# 2025-12-18 00:40:45 INFO [testing] [2022] [x137y175]: Using parameters {'study_area': 'x137y175', 'start_date': '2021', 'end_date': '2023', 'label_date': '2022', 'output_version': 'testing', 'output_dir': 'data/processed/', 'product_maturity': 'provisional', 'dataset_maturity': 'final', 'resolution': 10, 'threshold_lowtide': 0.15, 'threshold_hightide': 0.85, 'min_obs': 0, 'mask_sunglint': 20, 'gqa_filter': True, 'include_coastal_aerosol': True, 'eps': 0.0001, 'cpus': None, 'max_iters': 1000, 'tide_model': ('ensemble',), 'tide_model_dir': '/var/share/tide_models/', 'aws_unsigned': True, 'overwrite': False, 'datacube': <module 'datacube' from '/env/lib/python3.10/site-packages/datacube/__init__.py'>, 'configure_s3_access': <function configure_s3_access at 0x7f62053fe7a0>, 'filename': 'data/processed/ga_s2_tidal_composites_cyear_3/testing/x137/y175/2022--P1Y/ga_s2_tidal_composites_cyear_3_x137y175_2022--P1Y_final.stac-item.json', 'process_tile': True}
# <Client: 'tcp://127.0.0.1:46289' processes=1 threads=64, memory=456.00 GiB>
# 2025-12-18 00:41:05 INFO [testing] [2022] [x137y175]: Found 343 satellite data timesteps
# 2025-12-18 00:41:05 INFO [testing] [2022] [x137y175]: Running DEA Tidal Composites workflow
# 2025-12-18 00:41:05 INFO [testing] [2022] [x137y175]: Modelling tide heights for each pixel
# Creating reduced resolution 5000 x 5000 metre tide modelling array
# Running ensemble tide modelling
# Modelling tides with EOT20, FES2012, FES2014_extrapolated, FES2022_extrapolated, GOT4.10, GOT5.6_extrapolated, TPXO10-atlas-v2-nc, TPXO8-atlas-nc, TPXO9-atlas-v5-nc in parallel (models: 9, splits: 1)
# 100%|█████████████████████████████████████████████| 9/9 [00:22<00:00,  2.55s/it]
# Interpolating model rankings using IDW interpolation
# Combining models into single ensemble model
# Reprojecting tides into original resolution
# 2025-12-18 00:41:57 INFO [testing] [2022] [x137y175]: Loading red band to identify nodata pixels
# 2025-12-18 00:44:55 INFO [testing] [2022] [x137y175]: Calculating low and high tide thresholds with minimum 0 observations
# 2025-12-18 00:49:21 INFO [testing] [2022] [x137y175]: Loading 51 low tide satellite images into memory
# 2025-12-18 00:50:46 INFO [testing] [2022] [x137y175]: Loading 58 high tide satellite images into memory
# 2025-12-18 00:52:29 INFO [testing] [2022] [x137y175]: Running low tide geomedian with 62 threads
# 2025-12-18 00:54:10 INFO [testing] [2022] [x137y175]: Running high tide geomedian with 62 threads
# 2025-12-18 00:55:58 INFO [testing] [2022] [x137y175]: Calculating clear counts
# Using tide modelling location: 131.86, -12.29
# Running ensemble tide modelling
# Modelling tides with EOT20, FES2012, FES2014_extrapolated, FES2022_extrapolated, GOT4.10, GOT5.6_extrapolated, TPXO10-atlas-v2-nc, TPXO8-atlas-nc, TPXO9-atlas-v5-nc in parallel (models: 9, splits: 1)
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.77s/it]
# Interpolating model rankings using IDW interpolation
# Combining models into single ensemble model
# Using tide modelling location: 131.86, -12.29
# Running ensemble tide modelling
# Modelling tides with EOT20, FES2012, FES2014_extrapolated, FES2022_extrapolated, GOT4.10, GOT5.6_extrapolated, TPXO10-atlas-v2-nc, TPXO8-atlas-nc, TPXO9-atlas-v5-nc in parallel (models: 9, splits: 1)
# 100%|█████████████████████████████████████████████| 9/9 [00:21<00:00,  2.41s/it]
# Interpolating model rankings using IDW interpolation
# Combining models into single ensemble model
# 2025-12-18 00:56:53 INFO [testing] [2022] [x137y175]: Assembling dataset
# 2025-12-18 00:56:53 INFO [testing] [2022] [x137y175]: Writing output arrays
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# 2025-12-18 00:57:25 INFO [testing] [2022] [x137y175]: Assembled dataset: /tmp/tmpn5kisqk9/ga_s2_tidal_composites_cyear_3/testing/x137/y175/2022--P1Y/ga_s2_tidal_composites_cyear_3_x137y175_2022--P1Y_final.odc-metadata.yaml
# 2025-12-18 00:57:25 INFO [testing] [2022] [x137y175]: Writing data locally: data/processed/ga_s2_tidal_composites_cyear_3/testing/x137/y175/2022--P1Y/
# 2025-12-18 00:57:28 INFO [testing] [2022] [x137y175]: Completed DEA Tidal Composites workflow

# %% [markdown]
# ## Run DEA Intertidal and DEA Tidal Composites CLIs for multiple epochs
# This will run an entire DEA Intertidal and DEA Intertidal Composites analysis from start to finish for several epochs:

# %%
study_area = "testing"
tide_model = "ensemble"  # Tide model to use in analysis
tide_model_dir = "/var/share/tide_models/"  # Directory containing tide model files
output_version = "testing"  # Version number to label output files and metadata
epoch_list = [
    # ("2016", "2017", "2018"),
    # ("2017", "2018", "2019"),
    # ("2018", "2019", "2020"),
    ("2019", "2020", "2021"),
]

for start_date, label_date, end_date in epoch_list:
    print(start_date, label_date, end_date)
    # !python -m intertidal.elevation --study_area {study_area} --start_date {start_date} --end_date {end_date} --label_date {label_date} --output_dir {output_dir} --output_version {output_version} --modelled_freq {modelled_freq} --exposure_offsets {exposure_offsets} --tide_model {tide_model} --tide_model_dir {tide_model_dir}
    # !python -m intertidal.composites --study_area {study_area} --start_date {start_date} --end_date {end_date} --label_date {label_date}  --output_dir {output_dir} --output_version {output_version} --tide_model {tide_model} --tide_model_dir {tide_model_dir} --no-overwrite --threshold_lowtide {threshold_lowtide} --threshold_hightide {threshold_hightide}
# Out:
# 2019 2020 2021
# 2025-12-18 00:57:35 INFO [testing] [2020] [testing]: Using parameters {'study_area': 'testing', 'start_date': '2019', 'end_date': '2021', 'label_date': '2020', 'output_version': 'testing', 'output_dir': 'data/processed/', 'product_maturity': 'stable', 'dataset_maturity': 'final', 'resolution': 10, 'ndwi_thresh': 0.1, 'min_freq': 0.01, 'max_freq': 0.99, 'min_correlation': 0.15, 'windows_n': 100, 'window_prop_tide': 0.15, 'correct_seasonality': False, 'tide_model': ('ensemble',), 'tide_model_dir': '/var/share/tide_models/', 'modelled_freq': '3h', 'exposure_offsets': True, 'aws_unsigned': True, 'datacube': <module 'datacube' from '/env/lib/python3.10/site-packages/datacube/__init__.py'>, 'configure_s3_access': <function configure_s3_access at 0x7f6b7f90d000>}
# 2025-12-18 00:57:35 INFO [testing] [2020] [testing]: Loading satellite data
# <Client: 'tcp://127.0.0.1:34051' processes=1 threads=64, memory=456.00 GiB>
# 2025-12-18 00:57:41 INFO [testing] [2020] [testing]: Running in testing mode using custom study area
# 2025-12-18 00:57:47 INFO [testing] [2020] [testing]: Loading 317 satellite data timesteps
# Loading SRTM data at native 30 m resolution
# Adding GMW mangroves to starting points
# Applying HAT correction
# Running cost distance calculation
# Reprojecting back to original GeoBox resolution
# 2025-12-18 00:58:50 INFO [testing] [2020] [testing]: Calculating Intertidal Elevation
# 2025-12-18 00:58:50 INFO [testing] [2020] [testing]: Modelling tide heights for each pixel
# Creating reduced resolution 5000 x 5000 metre tide modelling array
# Running ensemble tide modelling
# Modelling tides with EOT20, FES2012, FES2014_extrapolated, FES2022_extrapolated, GOT4.10, GOT5.6_extrapolated, TPXO10-atlas-v2-nc, TPXO8-atlas-nc, TPXO9-atlas-v5-nc in parallel (models: 9, splits: 1)
# 100%|█████████████████████████████████████████████| 9/9 [00:24<00:00,  2.70s/it]
# Interpolating model rankings using IDW interpolation
# Combining models into single ensemble model
# Reprojecting tides into original resolution
# 2025-12-18 00:59:20 INFO [testing] [2020] [testing]: Masking nodata and adding tide heights to satellite data array
# 2025-12-18 00:59:20 INFO [testing] [2020] [testing]: Flattening satellite data array and filtering to intertidal candidate pixels
# 2025-12-18 00:59:20 INFO [testing] [2020] [testing]: Applying valid data mask to constrain study area
# Reducing analysed pixels from 7125 to 5286 (74.19%)
# 2025-12-18 00:59:20 INFO [testing] [2020] [testing]: Running per-pixel rolling median
# 100%|█████████████████████████████████████████| 105/105 [00:03<00:00, 30.56it/s]
# 2025-12-18 00:59:25 INFO [testing] [2020] [testing]: Modelling intertidal elevation
# Applying tidal interval interpolation to 200 intervals
# Applying rolling mean smoothing with radius 20
# 2025-12-18 00:59:25 INFO [testing] [2020] [testing]: Modelling intertidal uncertainty
# 2025-12-18 00:59:25 INFO [testing] [2020] [testing]: Unflattening data back to its original spatial dimensions
# 2025-12-18 00:59:25 INFO [testing] [2020] [testing]: Cleaning inaccurate upper intertidal pixels
# 2025-12-18 00:59:25 INFO [testing] [2020] [testing]: Successfully completed intertidal elevation modelling
# 2025-12-18 00:59:25 INFO [testing] [2020] [testing]: Calculating Intertidal Extents
# 2025-12-18 00:59:25 INFO [testing] [2020] [testing]: Calculating Intertidal Exposure
# Creating reduced resolution 5000 x 5000 metre tide modelling array
# Running ensemble tide modelling
# Modelling tides with EOT20, FES2012, FES2014_extrapolated, FES2022_extrapolated, GOT4.10, GOT5.6_extrapolated, TPXO10-atlas-v2-nc, TPXO8-atlas-nc, TPXO9-atlas-v5-nc in parallel (models: 9, splits: 1)
# 100%|█████████████████████████████████████████████| 9/9 [00:31<00:00,  3.48s/it]
# Interpolating model rankings using IDW interpolation
# Combining models into single ensemble model
# Returning low resolution tide array
# Calculating unfiltered exposure
# 2025-12-18 01:00:11 INFO [testing] [2020] [testing]: Calculating spread, offset and HAT/LAT/LOT/HOT layers
# Using tide modelling location: 136.33, -15.60
# Running ensemble tide modelling
# Modelling tides with EOT20, FES2012, FES2014_extrapolated, FES2022_extrapolated, GOT4.10, GOT5.6_extrapolated, TPXO10-atlas-v2-nc, TPXO8-atlas-nc, TPXO9-atlas-v5-nc in parallel (models: 9, splits: 1)
# 100%|█████████████████████████████████████████████| 9/9 [00:19<00:00,  2.11s/it]
# Interpolating model rankings using IDW interpolation
# Combining models into single ensemble model
# Using tide modelling location: 136.33, -15.60
# Running ensemble tide modelling
# Modelling tides with EOT20, FES2012, FES2014_extrapolated, FES2022_extrapolated, GOT4.10, GOT5.6_extrapolated, TPXO10-atlas-v2-nc, TPXO8-atlas-nc, TPXO9-atlas-v5-nc in parallel (models: 9, splits: 1)
# 100%|█████████████████████████████████████████████| 9/9 [00:19<00:00,  2.18s/it]
# Interpolating model rankings using IDW interpolation
# Combining models into single ensemble model
# 2025-12-18 01:00:54 INFO [testing] [2020] [testing]: Assembling dataset
# 2025-12-18 01:00:54 INFO [testing] [2020] [testing]: Writing output arrays
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# 2025-12-18 01:00:55 INFO [testing] [2020] [testing]: Assembled dataset: /tmp/tmp05pjv0wc/ga_s2ls_intertidal_cyear_3/testing/tes/ting/2020--P1Y/ga_s2ls_intertidal_cyear_3_testing_2020--P1Y_final.odc-metadata.yaml
# 2025-12-18 01:00:55 INFO [testing] [2020] [testing]: Writing data locally: data/processed/ga_s2ls_intertidal_cyear_3/testing/tes/ting/2020--P1Y/
# 2025-12-18 01:00:57 INFO [testing] [2020] [testing]: Completed DEA Intertidal workflow
# 2025-12-18 01:01:03 INFO [testing] [2020] [testing]: Using parameters {'study_area': 'testing', 'start_date': '2019', 'end_date': '2021', 'label_date': '2020', 'output_version': 'testing', 'output_dir': 'data/processed/', 'product_maturity': 'provisional', 'dataset_maturity': 'final', 'resolution': 10, 'threshold_lowtide': 0.15, 'threshold_hightide': 0.85, 'min_obs': 0, 'mask_sunglint': 20, 'gqa_filter': True, 'include_coastal_aerosol': True, 'eps': 0.0001, 'cpus': None, 'max_iters': 1000, 'tide_model': ('ensemble',), 'tide_model_dir': '/var/share/tide_models/', 'aws_unsigned': True, 'overwrite': False, 'datacube': <module 'datacube' from '/env/lib/python3.10/site-packages/datacube/__init__.py'>, 'configure_s3_access': <function configure_s3_access at 0x7f475f7ae7a0>, 'filename': 'data/processed/ga_s2_tidal_composites_cyear_3/testing/test/ing/2020--P1Y/ga_s2_tidal_composites_cyear_3_testing_2020--P1Y_final.stac-item.json', 'process_tile': True}
# <Client: 'tcp://127.0.0.1:40537' processes=1 threads=64, memory=456.00 GiB>
# 2025-12-18 01:01:09 INFO [testing] [2020] [testing]: Running in testing mode using custom study area
# 2025-12-18 01:01:14 INFO [testing] [2020] [testing]: Found 194 satellite data timesteps
# 2025-12-18 01:01:14 INFO [testing] [2020] [testing]: Running DEA Tidal Composites workflow
# 2025-12-18 01:01:14 INFO [testing] [2020] [testing]: Modelling tide heights for each pixel
# Creating reduced resolution 5000 x 5000 metre tide modelling array
# Running ensemble tide modelling
# Modelling tides with EOT20, FES2012, FES2014_extrapolated, FES2022_extrapolated, GOT4.10, GOT5.6_extrapolated, TPXO10-atlas-v2-nc, TPXO8-atlas-nc, TPXO9-atlas-v5-nc in parallel (models: 9, splits: 1)
# 100%|█████████████████████████████████████████████| 9/9 [00:20<00:00,  2.29s/it]
# Interpolating model rankings using IDW interpolation
# Combining models into single ensemble model
# Reprojecting tides into original resolution
# 2025-12-18 01:01:39 INFO [testing] [2020] [testing]: Loading red band to identify nodata pixels
# 2025-12-18 01:02:13 INFO [testing] [2020] [testing]: Calculating low and high tide thresholds with minimum 0 observations
# 2025-12-18 01:02:14 INFO [testing] [2020] [testing]: Loading 30 low tide satellite images into memory
# 2025-12-18 01:02:27 INFO [testing] [2020] [testing]: Loading 29 high tide satellite images into memory
# 2025-12-18 01:02:40 INFO [testing] [2020] [testing]: Running low tide geomedian with 62 threads
# 2025-12-18 01:02:41 INFO [testing] [2020] [testing]: Running high tide geomedian with 62 threads
# 2025-12-18 01:02:41 INFO [testing] [2020] [testing]: Calculating clear counts
# Using tide modelling location: 136.33, -15.60
# Running ensemble tide modelling
# Modelling tides with EOT20, FES2012, FES2014_extrapolated, FES2022_extrapolated, GOT4.10, GOT5.6_extrapolated, TPXO10-atlas-v2-nc, TPXO8-atlas-nc, TPXO9-atlas-v5-nc in parallel (models: 9, splits: 1)
# 100%|█████████████████████████████████████████████| 9/9 [00:23<00:00,  2.56s/it]
# Interpolating model rankings using IDW interpolation
# Combining models into single ensemble model
# Using tide modelling location: 136.33, -15.60
# Running ensemble tide modelling
# Modelling tides with EOT20, FES2012, FES2014_extrapolated, FES2022_extrapolated, GOT4.10, GOT5.6_extrapolated, TPXO10-atlas-v2-nc, TPXO8-atlas-nc, TPXO9-atlas-v5-nc in parallel (models: 9, splits: 1)
# 100%|█████████████████████████████████████████████| 9/9 [00:22<00:00,  2.49s/it]
# Interpolating model rankings using IDW interpolation
# Combining models into single ensemble model
# 2025-12-18 01:03:33 INFO [testing] [2020] [testing]: Assembling dataset
# 2025-12-18 01:03:33 INFO [testing] [2020] [testing]: Writing output arrays
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option CRS
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support creation option NODATA
# 2025-12-18 01:03:34 INFO [testing] [2020] [testing]: Assembled dataset: /tmp/tmpno8mckko/ga_s2_tidal_composites_cyear_3/testing/tes/ting/2020--P1Y/ga_s2_tidal_composites_cyear_3_testing_2020--P1Y_final.odc-metadata.yaml
# 2025-12-18 01:03:34 INFO [testing] [2020] [testing]: Writing data locally: data/processed/ga_s2_tidal_composites_cyear_3/testing/tes/ting/2020--P1Y/
# 2025-12-18 01:03:35 INFO [testing] [2020] [testing]: Completed DEA Tidal Composites workflow
